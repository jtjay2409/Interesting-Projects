# 20           1   7.277500   7.891650  45.7083  23.667214      75        1468
# 21           1   2.424346   3.953480  40.0000  11.521990      93         888
# 22           1   3.957390   4.941955  43.6522  16.522200     150         836
# 23           1   3.993043   5.896500  49.1739  10.608110      86        1330
# 24           2   9.162598  11.726300  61.6957   8.696332     186        1799
# 25           3   8.917500  10.180000  86.2500  19.687950      34         472
# 26           1   7.995000  10.985000  68.7500   7.627079      15         416
# 27           2   8.342598  11.165850  79.3043   8.261100      38        1129
# 28           1   8.057402  10.606300  65.1739   9.739455     123         975
# 29           1   8.877402  12.516100  72.2174   4.956834     140         956
#
#      cnt
# 0    985
# 1    801
# 2   1349
# 3   1562
# 4   1600
# 5   1606
# 6   1510
# 7    959
# 8    822
# 9   1321
# 10  1263
# 11  1162
# 12  1406
# 13  1421
# 14  1248
# 15  1204
# 16  1000
# 17   683
# 18  1650
# 19  1927
# 20  1543
# 21   981
# 22   986
# 23  1416
# 24  1985
# 25   506
# 26   431
# 27  1167
# 28  1098
# 29  1096

# %% [markdown]
# ### Identifying the continous and categorical variables

# %% [markdown]
# Columns to be dropped:
#     1. instant- doesnot give much insight
#     2. dteday - yr,mnth
#     3. casual - adding them we get the cnt
#     4. registered - adding them we get the cnt
#     5. temp- hight corelatted with a temp
# Continous Variable:
#     1.atemp     2.hum   3.windspeed
#
#
# Categorical Variables:
#     1. season    2.yr    3.mnth    4.holiday    5.weekday    6.workingday    7.weathersit

# %% [markdown]
# Creating dummy variables for the categorical variables:

# %%
sharing["season"] = sharing["season"].map({1:"spring", 2:"summer", 3:"fall", 4:"winter"})

# %%
sharing["season"].value_counts()
# Out:
# fall      188
# summer    184
# spring    180
# winter    178
# Name: season, dtype: int64

# %%
sharing["yr"] = sharing["yr"].map({0: 2018, 1:2019})
sharing["yr"].value_counts()
# Out:
# 2019    365
# 2018    365
# Name: yr, dtype: int64

# %%
sharing["mnth"].dtypes
# Out:
# dtype('int64')

# %%
sharing["mnth"] = sharing["mnth"].astype(object)

# %%
sharing["mnth"] = sharing["mnth"].map({1:"Jan", 2:"Feb", 3:"Mar", 4:"Apr", 5:"May", 6:"Jun", 7:"July", 8:"Aug", 9:"Sept", 10:"Oct", 11:"Nov", 12:"Dec"})
sharing["mnth"].value_counts()
# Out:
# Mar     62
# Aug     62
# Jan     62
# Oct     62
# Dec     62
# May     62
# July    62
# Apr     60
# Jun     60
# Nov     60
# Sept    60
# Feb     56
# Name: mnth, dtype: int64

# %%
sharing["holiday"] = sharing["holiday"].astype(object)
sharing["holiday"] = sharing["holiday"].map({1:"holiday",0:"NotHoliday"})
sharing["holiday"].value_counts()
# Out:
# NotHoliday    709
# holiday        21
# Name: holiday, dtype: int64

# %%
sharing["weekday"].dtype
sharing["weekday"] = sharing["weekday"].astype(object)
sharing["weekday"] = sharing["weekday"].map({0:"Sun", 1:"Mon", 2:"Tues", 3:"Wed", 4:"Thurs", 5:"Fri", 6:"Sat"})
sharing["weekday"].value_counts()
# Out:
# Mon      105
# Sun      105
# Sat      105
# Fri      104
# Tues     104
# Thurs    104
# Wed      103
# Name: weekday, dtype: int64

# %%
sharing["workingday"].dtype
sharing["workingday"] = sharing["workingday"].astype(object)
sharing["workingday"] = sharing["workingday"].map({0:"non_working", 1:"working"})
sharing["workingday"].value_counts()
# Out:
# working        499
# non_working    231
# Name: workingday, dtype: int64

# %%
sharing["weathersit"].dtype
sharing["weathersit"] = sharing["weathersit"].astype(object)
sharing["weathersit"] = sharing["weathersit"].map({1:"Clear", 2:"Mist", 3:"Light_snow",4:"Heavy_Rain"})
sharing["weathersit"].value_counts()
# Out:
# Clear         463
# Mist          246
# Light_snow     21
# Name: weathersit, dtype: int64

# %% [markdown]
# ### Visualising the data using seaborn lib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(sharing)
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.heatmap(sharing.corr(),annot = True, cmap = "YlGnBu")
plt.show()

# %% [markdown]
# ### We can see there are no missing rowsor data in the dataframe

# %%
sharing.count()
# Out:
# instant       730
# dteday        730
# season        730
# yr            730
# mnth          730
# holiday       730
# weekday       730
# workingday    730
# weathersit    730
# temp          730
# atemp         730
# hum           730
# windspeed     730
# casual        730
# registered    730
# cnt           730
# dtype: int64

# %%
sharing.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ### After converting the categorical vars from int to object, lets drop the columns that are highly correlated.

# %%
sharing.drop(['instant','dteday','casual','registered','temp'], axis=1)
# Out:
#      season    yr mnth     holiday weekday   workingday weathersit     atemp  \
# 0    spring  2018  Jan  NotHoliday     Sat  non_working       Mist  18.18125
# 1    spring  2018  Jan  NotHoliday     Sun  non_working       Mist  17.68695
# 2    spring  2018  Jan  NotHoliday     Mon      working      Clear   9.47025
# 3    spring  2018  Jan  NotHoliday    Tues      working      Clear  10.60610
# 4    spring  2018  Jan  NotHoliday     Wed      working      Clear  11.46350
# ..      ...   ...  ...         ...     ...          ...        ...       ...
# 725  spring  2019  Dec  NotHoliday   Thurs      working       Mist  11.33210
# 726  spring  2019  Dec  NotHoliday     Fri      working       Mist  12.75230
# 727  spring  2019  Dec  NotHoliday     Sat  non_working       Mist  12.12000
# 728  spring  2019  Dec  NotHoliday     Sun  non_working      Clear  11.58500
# 729  spring  2019  Dec  NotHoliday     Mon      working       Mist  11.17435
#
#          hum  windspeed   cnt
# 0    80.5833  10.749882   985
# 1    69.6087  16.652113   801
# 2    43.7273  16.636703  1349
# 3    59.0435  10.739832  1562
# 4    43.6957  12.522300  1600
# ..       ...        ...   ...
# 725  65.2917  23.458911  2114
# 726  59.0000  10.416557  3095
# 727  75.2917   8.333661  1341
# 728  48.3333  23.500518  1796
# 729  57.7500  10.374682  2729
#
# [730 rows x 11 columns]
